# %%
import os
import pandas as pd
from pathlib import Path

os.getcwd()
os.chdir('E:\\POLINEMA\\Semester 4 kelas TI 2E\\Statistik Komputasi\\Minggu 1\\pythonbook-main\\Data')

afl_finalists=pd.read_cvs('afl_finalists.cvs')
afl_margins=pd.read_cvs('afl_margins.cvs')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-6ebfbff43563> in <module>()
# ----> 1 os.chdir('E:\\POLINEMA\\Semester 4 kelas TI 2E\\Statistik Komputasi\\Minggu 1\\pythonbook-main\\Data')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\POLINEMA\\Semester 4 kelas TI 2E\\Statistik Komputasi\\Minggu 1\\pythonbook-main\\Data'

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
