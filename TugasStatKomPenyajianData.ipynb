# %%
print("Tugas Statistika Komputasi - Penyajian Data")
# Out:
# Tugas Statistika Komputasi - Penyajian Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot') #style.use → Gaya chart yang digunakan

import numpy as np
import statistics

# Menampilkan data nilai rapor Anjani Dwilestari
dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")

print (dataset)
# Out:
#      Mapel  Semester1  Semester2  Semester3  Semester4  Semester5  Semester6
# 0      PAI       79.0       80.0       81.0       82.0       84.0       92.0
# 1      PKN       86.0       87.0       86.5       87.5       89.5       91.0
# 2       BI       82.5       85.0       87.5       89.0       91.0       93.0
# 3      MAT       78.5       80.0       83.0       84.5       88.0       90.0
# 4       SI       80.5       82.0       84.5       85.5       87.5       89.0
# 5     BING       88.5       91.0       91.5       91.5       93.0       90.0
# 6       SB       85.0       85.0       86.5       87.5       88.5       89.0
# 7     PJOK       80.5       81.5       81.0       83.0       83.0       94.0
# 8     PRAK       86.5       85.0       85.0       85.5       87.0       89.5
# 9       BD       83.5       82.5       84.5       85.5       88.5       89.5
# 10  MATMIN       78.5       82.0       87.0       87.0       89.0       90.0
# ...

# %%
#Mencari Nilai Rata-Rata Semester 1 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata1 = dataset['Semester1'].mean()
mean1 = round(rerata1,1)
print ('Nilai Rata-rata Semester 1 adalah' ,mean1)
# Out:
# Nilai Rata-rata Semester 1 adalah 83.1

# %%
#Mencari Nilai Rata-Rata Semester 2 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata2 = dataset['Semester2'].mean()
mean2 = round(rerata2,1)
print ('Nilai Rata-rata Semester 2 adalah' ,mean2)
# Out:
# Nilai Rata-rata Semester 2 adalah 84.4

# %%
#Mencari Nilai Rata-Rata Semester 3 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata3 = dataset['Semester3'].mean()
mean3 = round(rerata3,1)
print ('Nilai Rata-rata Semester 3 adalah' ,mean3)
# Out:
# Nilai Rata-rata Semester 3 adalah 85.3

# %%
#Mencari Nilai Rata-Rata Semester 4 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata4 = dataset['Semester4'].mean()
mean4 = round(rerata4,1)
print ('Nilai Rata-rata Semester 4 adalah' ,mean4)
# Out:
# Nilai Rata-rata Semester 4 adalah 86.4

# %%
#Mencari Nilai Rata-Rata Semester 5 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata5 = dataset['Semester5'].mean()
mean5 = round(rerata5,1)
print ('Nilai Rata-rata Semester 5 adalah' ,mean5)
# Out:
# Nilai Rata-rata Semester 5 adalah 88.3

# %%
#Mencari Nilai Rata-Rata Semester 6 dari Keseluruhan Nilai Anjani

dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/rapor_anjani.csv")
rerata6 = dataset['Semester6'].mean()
mean6 = round(rerata6,1)
print ('Nilai Rata-rata Semester 6 adalah' ,mean6)
# Out:
# Nilai Rata-rata Semester 6 adalah 90.6

# %%
# Visualisasi Data 

data_mean=mean1, mean2, mean3, mean4, mean5, mean6
semester="1", "2", "3", "4", "5", "6"

print(data_mean)
print(semester)
# Out:
# (83.1, 84.4, 85.3, 86.4, 88.3, 90.6)
# ('1', '2', '3', '4', '5', '6')

# %%
#Menampilkan data dengan Grafik Perbandingan Horizontal
plt.barh(semester, data_mean)
plt.xlabel('Nilai Rata-Rata')
plt.ylabel('Semester')
plt.title('Nilai Rata-Rata Setiap Semester Rapor Anjani')
plt.show()

# %%
#Menampilkan data dengan Grafik Perbandingan Vertical

fig, ax = plt.subplots()

ax.bar(semester, data_mean, align='center')

ax.set_title('Nilai Rata-Rata Setiap Semester Rapor Anjani')
ax.set_ylabel('Nilai Rata-Rata')
ax.set_xlabel('Semester')

plt.show()

#Keterangan
#fig,ax → Menambahkan kolom figure dan axes pada sublplots()
#ax.bar → Membuat output persegi
#ax.set_title → Judul grafik
#ax.set_ylabel → Menamai garis vertikal
#ax.set_xlabel → Menamai garis horizontal
#plt.show → Menampilkan chart

# %%
#Menampilkan data dengan Grafik Garis

plt.plot(semester, data_mean)

plt.xlabel('Semester')
plt.ylabel('Nilai Rata-Rata')
plt.title('Nilai Rata-Rata Setiap Semester Rapor Anjani')

plt.grid(True)

plt.show()

#Keterangan:
#plt.plot(data_mean, semester) → Meletakkan posisi titik di x dan y
#plt.xlabel → Keterangan sumbu horizontal
#plt.ylabel → Keterangan sumbu vertikal
#plt.title → Judul chart
#plt.grid → Menampilkan garis grid
#plt.show → Menampilkan chart

# %%
#Menampilkan data dengan Diagram Kartesius

plt.title('Nilai Rata-Rata Setiap Semester Rapor Anjani')
plt.scatter(semester, data_mean,color="darkblue", marker='x', label='Nilai Mean Tiap Semester')


plt.xlabel('Semester')
plt.ylabel('Nilai Rata-Rata')

plt.grid(True)
plt.legend()

plt.show()

#Keterangan:
#plt.title → Judul dari chart
#plt.scatter → Properti pembentuk chart
#plt.xlabel → Keterangan sumbu horizontal
#plt.ylabel → Keterangan sumbu vertikal
#plt.grid → Apabila bernilai True, maka akan ditampilkan garis grid
#plt.legend → Titik-titik yang merupakan gabungan x dan y
#plt.show → Menampilkan chart
